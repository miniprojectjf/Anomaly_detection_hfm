# %%
cxcxvfrom google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import gc

# %%
path = "/content/drive/MyDrive/archive (1)/Train_Dst_NoAuction_DecPre_CF_7.txt"

data = pd.read_csv(path, header=None, sep=r"\s+")

print("Original dataset shape:", data.shape)
# Out:
# Original dataset shape: (149, 254750)

# %%
data = data.iloc[:-5]

print("After removing labels:", data.shape)
# Out:
# After removing labels: (144, 254750)

# %%
data = data.T

print("After transpose:", data.shape)
# Out:
# After transpose: (254750, 144)

# %%
X = data.astype(np.float32)

# %%
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

print("Normalized feature matrix shape:", X_scaled.shape)
# Out:
# Normalized feature matrix shape: (254750, 144)

# %%
np.save("/content/drive/MyDrive/FI2010/normalized_LOB_train.npy", X_scaled)

# %%
del data
del X
gc.collect()
# Out:
# 0

# %%
X = np.load("/content/drive/MyDrive/FI2010/normalized_LOB_train.npy")

print("Loaded normalized data:", X.shape)
# Out:
# Loaded normalized data: (254750, 144)

# %% [markdown]
# here's what claude gave

# %%
from google.colab import drive
import numpy as np
import os
from huggingface_hub import HfApi

# --- CONFIG ---
HF_TOKEN = "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"
HF_REPO = "Jaanusri/train"
SAVE_DIR = "/content/batches"
os.makedirs(SAVE_DIR, exist_ok=True)

api = HfApi()

# Create repo if it doesn't exist
api.create_repo(
    repo_id=HF_REPO,
    repo_type="dataset",
    token=HF_TOKEN,
    exist_ok=True  # won't error if it already exists
)
print("Repo ready ✓")

window_size = 100
batch_size = 10000
num_samples = X.shape[0] - window_size + 1
num_features = X.shape[1]

buffer = []
file_index = 0

def save_and_upload(buffer, file_index):
    batch = np.array(buffer, dtype=np.float32)
    local_path = f"{SAVE_DIR}/subseq_batch_{file_index}.npy"
    np.save(local_path, batch)
    print(f"Saved batch {file_index} locally, uploading to HF...")
    api.upload_file(
        path_or_fileobj=local_path,
        path_in_repo=f"subseq_batch_{file_index}.npy",
        repo_id=HF_REPO,
        repo_type="dataset",
        token=HF_TOKEN
    )
    print(f"Uploaded batch {file_index} to HuggingFace ✓")
    os.remove(local_path)

for i in range(num_samples):
    seq = X[i:i+window_size]
    buffer.append(seq)

    if len(buffer) == batch_size:
        save_and_upload(buffer, file_index)
        buffer = []
        file_index += 1

if len(buffer) > 0:
    save_and_upload(buffer, file_index)

print(f"Done. Total batches saved: {file_index + 1}")
# Out:
# Repo ready ✓
# Saved batch 0 locally, uploading to HF...
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#   ...atches/subseq_batch_0.npy:   0%|          | 1.53MB /  576MB
# Uploaded batch 0 to HuggingFace ✓
# Saved batch 1 locally, uploading to HF...
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#   ...atches/subseq_batch_1.npy:   2%|1         | 10.1MB /  576MB
# Uploaded batch 1 to HuggingFace ✓
# Saved batch 2 locally, uploading to HF...
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#   ...atches/subseq_batch_2.npy:   1%|1         | 7.95MB /  576MB
# Uploaded batch 2 to HuggingFace ✓
# Saved batch 3 locally, uploading to HF...
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# ...
